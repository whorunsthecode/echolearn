# %%
import cv2
import pytesseract
from PIL import Image, ImageDraw, ImageFont
from docx import Document
import numpy as np

# Optional: Windows path to tesseract.exe
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Use phone camera or webcam
# Example IP Cam: "http://192.168.x.x:4747/video"
cap = cv2.VideoCapture("http://192.168.19.116:4747/video")
# cap = cv2.VideoCapture(0)  # Use this for regular webcam

# Overlay height and visual settings
overlay_height = 180
LINE_SPACING = 40
FONT_SIZE = 24  # ~16pt

# Colors (RGB for PIL)
PASTEL_BLUE = (204, 229, 255)
DARK_GRAY = (64, 64, 64)

# Load OpenDyslexic font
font_path = "OpenDyslexic-Regular.ttf"
try:
    font = ImageFont.truetype(font_path, FONT_SIZE)
except IOError:
    print(f"Font '{font_path}' not found. Please place the TTF file in the script folder.")
    exit()

# Store OCR results
recognized_lines = []

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Resize frame
    frame = cv2.resize(frame, (640, 480))

    # Convert to grayscale for OCR
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # OCR: Extract text
    text = pytesseract.image_to_string(gray, lang='eng')

    # Convert OpenCV frame to PIL image
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(rgb_frame)
    draw = ImageDraw.Draw(pil_img)

    # Draw pastel blue rectangle for overlay
    draw.rectangle([(0, 0), (640, overlay_height)], fill=PASTEL_BLUE)

    # Render text line by line using OpenDyslexic font
    y = 10
    for line in text.strip().split('\n'):
        line = line.strip()
        if not line:
            continue

        # Simulate letter spacing by adding spaces
        spaced_line = ' '.join(list(line))

        draw.text((10, y), spaced_line, font=font, fill=DARK_GRAY)
        recognized_lines.append(line)
        y += LINE_SPACING
        if y > overlay_height - 10:
            break

    # Convert back to OpenCV image and display
    result_frame = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    cv2.imshow("Dyslexia-Friendly Live OCR", result_frame)

    # Press 'q' to quit and save
    if cv2.waitKey(1) & 0xFF == ord('q'):
        # Save to .txt
        with open("recognized_text.txt", "w", encoding="utf-8") as f:
            f.write("\n".join(recognized_lines))

        # Save to .docx
        doc = Document()
        doc.add_heading("OCR Captured Text", level=1)q
        for line in recognized_lines:
            doc.add_paragraph(line)
        doc.save("recognized_text.docx")

        print("Saved: recognized_text.txt and recognized_text.docx")
        break

# Clean up
cap.release()
cv2.destroyAllWindows()

# %%
# Read contents from recognized_text.txt
with open("recognized_text.txt", "r", encoding="utf-8") as file:
    text_content = file.read()

print("Text file content:")
print(text_content)
# Out:
# Text file content:
# vail inn
# ‘hava are
# »  Parennal ee ane \
# Multi-side
# customer Relatio
# customer Relationships
# tour 9 90"
# a Warm!"
# fawieniatl jornaniil anaananens
# ded markets
# Relationships
# Thee we 2
# » Personal assistance
# + Dedicated personal asst anc
# aqutioniaat ana
# couatonner elationetP
# | persone! #8
# © Dewiest*
# 7 eaipservic®
# ips
# ar Relations!
# + Dedic cesses OF
# eee
# —*
# otationships
# stance’
# Multi-sid
# custome!
# here
# Relation’
# 1s eee
# ‘Tote ""
# wnvern
# ane
# using droi
# using droid
# Components of Busines Canvas Mode!
# 1. Customer Segments
# Mas maka: Tis forse nh gener pepo on
# + Whe maria: Het ass crt na pec grup of peopl thug
# + Sopmanind: Baton sight tert reds, tare cube dere ape wn he
# {onan Spm
# Semen oe hoe en ene dens yn yn
# Ded ern aaah: Ai ih no
# 1, tor Sagrees
# © Mabe mata Hee
# {Parton estan: Yosh ve,
# > tin
# 1. Customer Sepnees
# Tosa he ges
# Dest sane semen shai
# + Mass mara: oases oy
# st ra can et
# + Mose ata
# {Pelt ee nets ats.
# “ont 8 wtin be nan cones apne
# droidcam.app
# if
# 4. Cuntore Segments
# + Mass mat: Ths sso he grr popltion are grup cf onl wl
# 1 Nee make H fe goupl peal ih ga nets
# + ier
# Components fa Busnes Canvas Mods
# 1. Gunter Segments
# ‘+ Maes mart T ses nh geal ppuin oa lage po of ep wth
# + Nebe make H fe guppies ats
# + Segmented cote tro pugs
# Components of Business Canvas Model
# 4. Customer Sapmens
# 4+ Mans mart Ti axe nn ger popu oye ga lap wih sir ees Far xa, 2
# rod hea toe.
# 1+ Nee mare Hee ers cotton see grup of api wh que nets ar as,
# using droidcam.
# using droidcam.a
# using droidcam.
# using droideca
# using droidc
# using droidcan
# droidcam.
# using droidcam.
# using droi
# using droidcam.app
# using droidcam.app
# using droidcam.app
# i dcam.app
# using dro
# using dr
# using droidcal
# using droidcam
# using droidcam.
# using droidcam.
# using droidcam.ap
# using droidcam.ap
# using droidcam.ap
# using droidcam.ap
# using droidcam.
# using droidcam.
# using droidcam.
# using droidcam.
# using droidcam.
# using droidcam.a
# using droidcam.a
# using droidcam.a
# using droidcam.a
# using droj
# using droi
# using droi
# using dro
# using droj
# using droide
# using droidg
# dcam.app
# idcam.app
# idcam.app
# ae kan
# aint
# a
# a
# oS
# using droidcam.app
# using droidcam.app
# USING Groigdecam.app
# cam.app
# cam.app
# using droid
# f
# + i
# using droid
# f
# + nto:
# tld mace
# using droid
# i
# H a
# using droid app
# Components of Business Canvas Mode
# Segments
# using droid m=)
# :
# 4 Business Canvas Mode
# Components of aB
# 4, Customer Segments
# Components ofa Business Canvas Model
# 4, Customer Segments
# 4 Mags market
# ate art
# using droidcam.
# using droidcam.
# using droidcam.
# using droidcam.d
# Mase martet
# Niche market
# + Segmented
# Dwversshed
# mut-sided markets
# vents of Business Canvas Model
# Mass
# che market
# Segmented
# Diversified: A
# Components of a Business Canves Model
# 1. Customer Segments
# + Mans market
# Whiche market
# nted
# Mase marnet
# Niche market
# Segmented:
# Mutp-sided
# anva8 Mode!
# Components of a Business Canvas Model
# + Maps market
# Wuche market
# + Segmented
# Mult-side:
# + Mans morte
# Customer Relabonship
# arvve Mod
# ws
# rr
# fp-wed marnets
# stomer Reiatonships
# Act
# Niche
# Segmented
# Diversified
# Mutb-sided marnets
# Components of » Bueinees Canvas Mode!
# + Niche market
# + Segmented
# + Diversified: A
# + Mul.sided markets:
# Components of # Business Canvas Model
# 1, Customer Segments
# + Ma
# + Niche market
# + Segmented
# Components of a Business Cameos Model
# 1, Customer Segments
# + Wiehe
# + Segmented
# sited m
# 1, Customer Segme
# + Niche market "
# + Segmented "
# + Diversified: A a
# + Mult-sided markets
# g droidcam.app
# f
# Customer Segments
# + Mans market
# + Niche market
# using droidcam.app
# 1, Customer Segments
# + Niche market:
# + Segmented
# . an
# using droidcam.app
# 1, Customer Segments
# + Mass market
# + Niche market: H
# + Segmented: 8 te
# using droidcam.app
# using droidcam.app
# using droidcam.app
# using droidcam.app
# Using droidcam.app
# using droidcam.app
# using droidcam.
# using droidcam.app
# using droidcam.app
# using droidcam.app
# using droidcam.app
# using droidcam.app
# using droidcam.app
# using droidcam.app
# using droidcam.
# using droidcam.app
# using droidcam.
# USing droidcam.app
# USing droidcam.app
# 4
# ugWng droidcam.app
# “a
# y -
# Using drOidcam.app
# a
# a
# using dmoidcam.app
# using Oro
# using dro
# Gu using dra
# using dra
# using drg
# Using dr
# using droidcam.app
# ris ofa Business Co
# ompone
# 4, customer SA
# Mas narte
# using droidcam.app
# ota Busines
# components 0
# rc at
# sgn
# using droidcam.app
# using droidc
# ose
# cuntra Sgnen
# ate ana ee
# gr
# using droidcam.app
# + Na nt Mee
# + Sapmented ano
# + Denied
# + Mahe
# using droidcam.app
# Components of Business Canvas Mode
# 1. Customer Sopmans
# «Mass markt: This fuses on th gone population or a large grupo pope wit sini n
# pact aoa pone
# using droidcam.app
# + Mavs moral Te
# +N marta Her
# Le
# using droidcam.app
# Components ofa Business Canvas Model
# 4, Customer Segments
# + Nice market
# + Segmented: Based o
# using droidcam.app
# Components of a Business Canvas Mode
# 4, Customer Segments
# «+ Mags market: This locuses an he general population arg gro
# roduc 3 phone
# using droidcam.app
# 1 Conys Mosel
# + Mass market
# Niche make
# 4+ Sapient: 8
# ‘+ Divesifed
# using droidcam.app
# components of» Busnes Canvas Model
# 4, Customer Segments
# 4 Mass mart Tis fox
# «Mee mart: Here esis cet on 2 speci OUP riqu
# using droidcam.app
# ines Canvas Mode
# Component ofa Business C
# 4. Customer Segments
# «Ni market: Herta 0
# using droidcam.app
# {customer Segments
# Niche markt Her
# Segmented: Base
# spoons of a Business Canvas Mod
# using droidcam.app
# ents of Business Canvas Model
# 4. Customer Sopments
# «Mays market: Ts fois en he gone
# + Nee mart: Her
# using droidcam.app
# Components of Business Canvas Mode
# + Mavs marie
# + Niche mart:
# using droidcam.
# tos Business Canvas Model
# 4. Customer Segment
# using droidcam.app
# Components of Business Canvas Model
# 4. Customer Segments
# + Mops market
# using droidcam.app
# ponents ofa Business Canvas Mode
# 4. Customer Segments
# + Mass market
# Niche market: Hee
# using droidcam.app
# 2 Business Canvas Mode
# Components of
# Customer Segments
# + Mass market
# using droidcam.app
# siness Canvas Model
# using droidcam.app
# using droidcam.app
# Components ofa Business Canvas Model
# 1, Customer Segments
# + Mass market:
# + Niche market:
# Niche market
# Segmented tisee
# Diverwified A ove
# Mutt sided manners
# Componente of a Business Canvas Moet
# 1, Customer Segments
# + Niche market bere the tr
# + Segmented: &
# + Diversified: A cover
# Componente of a Buvinnns Comes Mote!
# 4, Customer Segenente
# 5 Wane marten Hoon we te # Or
# + Ragmnonied: Bane 0” OF nee
# + Diversified A oom" wna oy
# Componente of 0 Bosinenn Coens tote
# + Mane marta
# + Niche mart rere
# ‘ Covered A over
# ® dui aided mart
# Componente of » Businens Comers Hote
# 1 Cutonner fomgeneerte
# + Whee anette
# eve aaron er
# + Segmented bev
# frvert nents, ave
# ak eager en
# + Mtoe marta: hin Hosen on te ger Penn
# + Segmented .
# + averted: A cvernind mart Sy
# + Mutbaited mantel vhertever ee
# 2 Customer Retanonsns
# Componente of s Brveinens Conve Mote!
# memes eager
# Componente o a tusinena conven Moet
# 1 Customer Sexgenet®
# on wet oe
# ‘Components of a Business Canvas Mode!
# 4, Customer Segments
# These are the groups of people or companies that you are tying to target an
# sell your product or
# Different customer segments a business model can target
# Components of a Business Canvas Model
# 4, Customer Segments
# These ae the groups of penpleor companies tal you ae tying 10 aget and sellyo
# Different customer segments a business model can target,
# «Mass market This fouses onthe general puto o large group of people th si
# Components of a Business Canvas Model
# 4, Customer Segments
# These are the groups of people or companies that you are trying to target and se
# Different customer segments a business model can target
# + Mass market: This focuses on the general population or a large group of people
# Components of a Business Canvas Model
# 4, Customer Segments
# ‘These are the groups of people or companies that you are trying to target and sell your pro
# Different customer segments a business model can target;
# is focuses on the general population ora large group of people with sir
